# %%
# !pip install openai IPython

# %%
import openai

openai.api_key = "" # Add your OpenAI API key here!

# MODEL = "gpt-4" # 8K context	$0.03 / 1K tokens	$0.06 / 1K tokens (Expensive!)
MODEL = "gpt-3.5-turbo" # gpt-3.5-turbo	$0.002 / 1K tokens


def get_completion(prompt_to_gpt, model=MODEL):
    messages = [{"role": "user", "content": prompt_to_gpt}]
    response_from_gpt = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0,  # this is the degree of randomness of the model's output
    )
    return response_from_gpt.choices[0].message["content"]

fact_sheet_chair = """
OVERVIEW
- Part of a beautiful family of mid-century inspired office furniture, 
including filing cabinets, desks, bookcases, meeting tables, and more.
- Several options of shell color and base finishes.
- Available with plastic back and front upholstery (SWC-100) 
or full upholstery (SWC-110) in 10 fabric and 6 leather options.
- Base finish options are: stainless steel, matte black, 
gloss white, or chrome.
- Chair is available with or without armrests.
- Suitable for home or business settings.
- Qualified for contract use.

CONSTRUCTION
- 5-wheel plastic coated aluminum base.
- Pneumatic chair adjust for easy raise/lower action.

DIMENSIONS
- WIDTH 53 CM | 20.87”
- DEPTH 51 CM | 20.08”
- HEIGHT 80 CM | 31.50”
- SEAT HEIGHT 44 CM | 17.32”
- SEAT DEPTH 41 CM | 16.14”

OPTIONS
- Soft or hard-floor caster options.
- Two choices of seat foam densities: 
 medium (1.8 lb/ft3) or high (2.8 lb/ft3)
- Armless or 8 position PU armrests 

MATERIALS
SHELL BASE GLIDER
- Cast Aluminum with modified nylon PA6/PA66 coating.
- Shell thickness: 10 mm.
SEAT
- HD36 foam

COUNTRY OF ORIGIN
- Italy
"""
# prompt was too long!
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)

# clarify the prompt
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)

prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)

prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

After the description, include a table that gives the 
product's dimensions. The table should have two columns.
In the first column include the name of the dimension. 
In the second column include the measurements in inches only.

Give the table the title 'Product Dimensions'.

Format everything as HTML that can be used in a website. 
Place the description in a <div> element.

Technical specifications: ```{fact_sheet_chair}```
"""

response = get_completion(prompt)
print(response)

from IPython.display import display, HTML
display(HTML(response))
# Out:
# Introducing our stunning mid-century inspired office chair, designed to complement any home or business setting. As part of our exquisite collection of office furniture, this chair is available in a variety of shell colors and base finishes, allowing you to create the perfect look for your workspace.
#
# Choose between a plastic back and front upholstery (SWC-100) or a fully upholstered design (SWC-110) with 10 fabric and 6 leather options to suit your style. The base finish options include stainless steel, matte black, gloss white, or chrome, ensuring a seamless fit with your existing décor.
#
# Customize your chair with or without armrests, and select from soft or hard-floor caster options for optimal mobility. The 5-wheel plastic coated aluminum base provides stability, while the pneumatic chair adjust allows for easy raise and lower action.
#
# With dimensions of 53 cm (20.87") width, 51 cm (20.08") depth, and 80 cm (31.50") height, this chair offers a comfortable seating experience. The seat height is 44 cm (17.32") and the seat depth is 41 cm (16.14"). Choose between two seat foam densities: medium (1.8 lb/ft3) or high (2.8 lb/ft3) for your preferred level of comfort.
#
# The chair's shell base glider is made of cast aluminum with a modified nylon PA6/PA66 coating, ensuring durability and a shell thickness of 10 mm. The seat is crafted with high-quality HD36 foam for added comfort.
#
# Proudly made in Italy, this office chair is not only stylish but also qualified for contract use. Enhance your workspace with this elegant and versatile mid-century inspired office chair, designed to meet your unique needs and preferences.
# Upgrade your office with our mid-century inspired chair, available in various shell colors and base finishes. Customize with 10 fabric and 6 leather options, armrests, and caster types. Featuring a 5-wheel coated aluminum base and pneumatic adjust for easy height changes. Perfect for home or business use.
# Introducing our mid-century inspired office chair, featuring a 10mm thick cast aluminum shell with PA6/PA66 coating and a comfortable HD36 foam seat. Choose from various shell colors, base finishes, and upholstery options. Available with or without armrests. Product IDs: SWC-100, SWC-110.
# <div>
#   <p>Introducing our mid-century inspired office chair, designed to complement a wide range of office furniture including filing cabinets, desks, bookcases, meeting tables, and more. This versatile chair is available in several shell colors and base finishes, making it the perfect addition to any home or business setting. Choose between plastic back and front upholstery (SWC-100) or full upholstery (SWC-110) in 10 fabric and 6 leather options. Base finish options include stainless steel, matte black, gloss white, or chrome. The chair is available with or without armrests and is qualified for contract use.</p>
#
#   <p>Constructed with a 5-wheel plastic coated aluminum base, this chair offers stability and durability. The pneumatic chair adjust allows for easy raise/lower action, ensuring maximum comfort for users. The chair also offers soft or hard-floor caster options, two choices of seat foam densities (medium 1.8 lb/ft3 or high 2.8 lb/ft3), and the option for armless or 8 position PU armrests.</p>
#
#   <p>The shell base glider is made from cast aluminum with a modified nylon PA6/PA66 coating, providing a shell thickness of 10 mm. The seat is made from high-quality HD36 foam, ensuring comfort and durability. This chair is proudly made in Italy.</p>
#
#   <p>Product IDs: SWC-100, SWC-110</p>
# </div>
#
# <h3>Product Dimensions</h3>
# <table>
#   <tr>
#     <th>Dimension</th>
#     <th>Measurement (inches)</th>
#   </tr>
#   <tr>
#     <td>Width</td>
#     <td>20.87</td>
#   </tr>
#   <tr>
#     <td>Depth</td>
#     <td>20.08</td>
#   </tr>
#   <tr>
#     <td>Height</td>
#     <td>31.50</td>
#   </tr>
#   <tr>
#     <td>Seat Height</td>
#     <td>17.32</td>
#   </tr>
#   <tr>
#     <td>Seat Depth</td>
#     <td>16.14</td>
#   </tr>
# </table>
# <div>
#   <p>Introducing our mid-century inspired office chair, designed to complement a wide range of office furniture including filing cabinets, desks, bookcases, meeting tables, and more. This versatile chair is available in several shell colors and base finishes, making it the perfect addition to any home or business setting. Choose between plastic back and front upholstery (SWC-100) or full upholstery (SWC-110) in 10 fabric and 6 leather options. Base finish options include stainless steel, matte black, gloss white, or chrome. The chair is available with or without armrests and is qualified for contract use.</p>
#
#   <p>Constructed with a 5-wheel plastic coated aluminum base, this chair offers stability and durability. The pneumatic chair adjust allows for easy raise/lower action, ensuring maximum comfort for users. The chair also offers soft or hard-floor caster options, two choices of seat foam densities (medium 1.8 lb/ft3 or high 2.8 lb/ft3), and the option for armless or 8 position PU armrests.</p>
#
#   <p>The shell base glider is made from cast aluminum with a modified nylon PA6/PA66 coating, providing a shell thickness of 10 mm. The seat is made from high-quality HD36 foam, ensuring comfort and durability. This chair is proudly made in Italy.</p>
#
#   <p>Product IDs: SWC-100, SWC-110</p>
# </div>
#
# <h3>Product Dimensions</h3>
# <table>
#   <tr>
#     <th>Dimension</th>
#     <th>Measurement (inches)</th>
#   </tr>
#   <tr>
#     <td>Width</td>
#     <td>20.87</td>
#   </tr>
#   <tr>
#     <td>Depth</td>
#     <td>20.08</td>
#   </tr>
#   <tr>
#     <td>Height</td>
#     <td>31.50</td>
#   </tr>
#   <tr>
#     <td>Seat Height</td>
#     <td>17.32</td>
#   </tr>
#   <tr>
#     <td>Seat Depth</td>
#     <td>16.14</td>
#   </tr>
# </table>
